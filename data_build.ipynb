# %%
import json
import pandas as pd

# %%
data = pd.read_json("Original_Data/yelp_academic_dataset_business_cleaned.json",lines=True, orient='columns')

# %%
data.head()
# Out:
#               business_id                      name  \
# 0  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 1  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 2  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# 3  CF33F8-E6oudUQ46HnavjQ            Sonic Drive-In
# 4  n_0UpQx1hsNbnPUSlodU8w           Famous Footwear
#
#                                       address          city state postal_code  \
# 0             87 Grasso Plaza Shopping Center        Affton    MO       63123
# 1                                 935 Race St  Philadelphia    PA       19107
# 2                               101 Walnut St    Green Lane    PA       18054
# 3                               615 S Main St  Ashland City    TN       37015
# 4  8522 Eager Road, Dierbergs Brentwood Point     Brentwood    MO       63144
#
#     latitude  longitude  stars  review_count  is_open  \
# 0  38.551126 -90.335695    3.0            15        1
# 1  39.955505 -75.155564    4.0            80        1
# ...

# %%
import json

# Assuming your DataFrame is named 'data'
json_data = []

for index, row in data.iterrows():
    entry = {}
    for col in data.columns:
        entry[col] = row[col]
    json_data.append(entry)

# Now 'json_data' contains the list of dictionaries, one for each row

# Specify the path for the JSON file
json_file_path = 'dataForLLama/business_context.json'

# Write the JSON data to the file
with open(json_file_path, 'w') as json_file:
    json.dump(json_data, json_file, indent=4)

print(f'Data has been written to {json_file_path}')
# Out:
# Data has been written to dataForLLama/business_context.json

# %%
## For Model training 

data['Text'] = '<s>[INST] What is the name of the store? [/INST]' + data["name"] +'</s>'+ \
            ' <s>[INST] Where is it located? [/INST]' + data["address"]+'</s>'\
            ' <s>[INST] What type of food is served? [/INST]' + data["categories"]+'</s>'

# %%
# Convert 'Text' column to JSON format
json_data = [{"text": text} for text in data['Text']]

# Specify the path for the JSON file
json_file_path = 'dataForLLama/business_training_data.json'

# Write the JSON data to the file
with open(json_file_path, 'w') as json_file:
    json.dump(json_data, json_file, indent=4)

print(f'Data has been written to {json_file_path}')
# Out:
# Data has been written to dataForLLama/business_training_data.json
