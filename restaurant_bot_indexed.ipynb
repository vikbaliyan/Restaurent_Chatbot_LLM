# %%
# !nvidia-smi
# Out:
# Fri Aug 18 22:23:40 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install --upgrade huggingface_hub
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 5.6 MB/s eta 0:00:00
# ...

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !pip install -q transformers einops accelerate langchain bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 18.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 20.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 28.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 102.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.1 MB/s eta 0:00:00

# %%
# !pip install sentence_transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 15.6 MB/s eta 0:00:00
# ...
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125924 sha256=38d94d6b99c448cf439f8e9a5579f6201b06098ff443c21a234dab2d24993f9b
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence_transformers
# ...

# %%
# !pip install llama-index
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 673.8/673.8 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 15.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 23.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 kB 17.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 24.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.4
#     Uninstalling urllib3-2.0.4:
#       Successfully uninstalled urllib3-2.0.4
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.1.1
#     Uninstalling pydantic-2.1.1:
#       Successfully uninstalled pydantic-2.1.1
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.0.268
# ...

# %%
# !pip install llama-cpp-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 8.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 kB 3.4 MB/s eta 0:00:00
# ...
#   Created wheel for llama-cpp-python: filename=llama_cpp_python-0.1.78-cp310-cp310-linux_x86_64.whl size=296587 sha256=d4cf08c950e5261e02de529f71617fbc9781fcc1012b4bcb4d41c088784150b7
#   Stored in directory: /root/.cache/pip/wheels/61/f9/20/9ca660a9d3f2a47e44217059409478865948b5c8a1cba70030
# Successfully built llama-cpp-python
# ...

# %%
! pip install flask-ngrok flask-bootstrap jsonify flask_cors
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 456.4/456.4 kB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for flask-bootstrap: filename=Flask_Bootstrap-3.3.7.1-py3-none-any.whl size=460120 sha256=016c1864f05a9949dbf2885021843aac307775409930bc7e1e728fa3edf8107a
#   Stored in directory: /root/.cache/pip/wheels/6f/33/ad/26540e84a28334e5dfeda756df270f95353779f03bc5cf40d4
# ...
#   Created wheel for jsonify: filename=jsonify-0.5-py3-none-any.whl size=1539 sha256=f0ff0cbf940b3297a065d3144e12f8c85762217263836742642c9b3f24f194df
#   Stored in directory: /root/.cache/pip/wheels/4e/6d/b2/9cb590fb5654ff13457f49d4aa5b16469419681613c46a2ec1
# ...
#   Created wheel for visitor: filename=visitor-0.1.3-py3-none-any.whl size=3927 sha256=212ab637031944107c9fe80e7b02836f672032410e9889886a66f79623da9637
# ...

# %%
# !pip install pydantic==1.10.9
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 11.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.12
#     Uninstalling pydantic-1.10.12:
#       Successfully uninstalled pydantic-1.10.12
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
from llama_index import VectorStoreIndex, SimpleDirectoryReader, ServiceContext, Document, GPTVectorStoreIndex
from llama_index.llms import HuggingFaceLLM
from langchain.llms import HuggingFacePipeline, LlamaCpp
from huggingface_hub import hf_hub_download
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    TrainingArguments,
    pipeline,
    logging,
)

from langchain.embeddings.huggingface import HuggingFaceEmbeddings
from llama_index import LangchainEmbedding, ServiceContext
from llama_index.embeddings import OpenAIEmbedding

# %%
import torch
import pandas as pd

# %%
df = pd.read_json('/content/yelp_academic_dataset_business_cleaned.json', lines=True, orient='records')
df.head()
# Out:
#               business_id                                 name  \
# 0  mWMc6_wTdE0EUBKIGXDVfA             Perkiomen Valley Brewery
# 1  kV_Q1oqis8Qli8dUoGpTyQ                        Ardmore Pizza
# 2  txyXRytGjwOXvS8s4sc-WA                        Smoothie King
# 3  ljxNT9p0y7YMPx0fcNBGig  Tony's Restaurant & 3rd Street Cafe
# 4  lOP3HxdUTaq0eXhwR_KC-w              Sweet Things Chocolates
#
#                           address          city state postal_code   latitude  \
# 0                   101 Walnut St    Green Lane    PA       18054  40.338183
# 1               10 Rittenhouse Pl       Ardmore    PA       19003  40.006707
# 2  1070 E Tucson Marketplace Blvd        Tucson    AZ       85713  32.186794
# 3                    312 Piasa St         Alton    IL       62002  38.896563
# 4                  2288 W 86th St  Indianapolis    IN       46260  39.913292
#
#     longitude  stars  review_count  is_open  \
# 0  -75.471659    4.5            13        1
# ...

# %%
def make_text(row):
    text = "{} is located at {}. It has a rating of {} with {} reviews. The cusinine served by the restaurant is {}.".format(row['name'], row['address'],row['stars'], row['review_count'], row['categories'])
    hours = row['hours']
    if hours is not None:
        timings = ', '.join([str(x)+' - '+str(y) for x,y in hours.items() ])
        text += ' The restaurant timings are {}.'.format(timings)

    d = row['attributes']
    if d is not None:
        services = ', '.join([str(x) for x in d if d[x]=='True'])
        text += ' The restaurant offers these services - {}'.format(services)
    return text


df['text'] = df.apply(lambda x: make_text(x),axis=1)

# %%
docs = list(df['text'][0:5].values)
docs.append("Hello , I am FlavourQuestAI. I'm a chat bot for Restaurant recommendation. Please give some info about restaurant search." )
print(docs)
# Out:
# ['Perkiomen Valley Brewery is located at 101 Walnut St. It has a rating of 4.5 with 13 reviews. The cusinine served by the restaurant is Brewpubs, Breweries, Food. The restaurant timings are Wednesday - 14:0-22:0, Thursday - 16:0-22:0, Friday - 12:0-22:0, Saturday - 12:0-22:0, Sunday - 12:0-18:0. The restaurant offers these services - BusinessAcceptsCreditCards, WheelchairAccessible, RestaurantsTakeOut, BikeParking, GoodForKids', 'Ardmore Pizza is located at 10 Rittenhouse Pl. It has a rating of 3.5 with 109 reviews. The cusinine served by the restaurant is Pizza, Restaurants. The restaurant timings are Monday - 11:0-0:0, Tuesday - 11:0-0:0, Wednesday - 11:0-0:0, Thursday - 11:0-0:0, Friday - 11:0-1:0, Saturday - 11:0-1:0, Sunday - 11:0-0:0. The restaurant offers these services - RestaurantsGoodForGroups, GoodForKids, HasTV, RestaurantsTakeOut, BusinessAcceptsCreditCards, RestaurantsDelivery, BikeParking, Caters', 'Smoothie King is located at 1070 E Tucson Marketplace Blvd. It has a 
# ...

# %%
print(docs)
# Out:
# ['Perkiomen Valley Brewery is located at 101 Walnut St. It has a rating of 4.5 with 13 reviews. The cusinine served by the restaurant is Brewpubs, Breweries, Food. The restaurant timings are Wednesday - 14:0-22:0, Thursday - 16:0-22:0, Friday - 12:0-22:0, Saturday - 12:0-22:0, Sunday - 12:0-18:0. The restaurant offers these services - BusinessAcceptsCreditCards, WheelchairAccessible, RestaurantsTakeOut, BikeParking, GoodForKids', 'Ardmore Pizza is located at 10 Rittenhouse Pl. It has a rating of 3.5 with 109 reviews. The cusinine served by the restaurant is Pizza, Restaurants. The restaurant timings are Monday - 11:0-0:0, Tuesday - 11:0-0:0, Wednesday - 11:0-0:0, Thursday - 11:0-0:0, Friday - 11:0-1:0, Saturday - 11:0-1:0, Sunday - 11:0-0:0. The restaurant offers these services - RestaurantsGoodForGroups, GoodForKids, HasTV, RestaurantsTakeOut, BusinessAcceptsCreditCards, RestaurantsDelivery, BikeParking, Caters', 'Smoothie King is located at 1070 E Tucson Marketplace Blvd. It has a 
# ...

# %%
documents = [Document(text=t) for t in docs]

# %%
from llama_index.prompts.prompts import SimpleInputPrompt

system_prompt = "You are a restaurant Q&A assistant named FlavourQuestAI. Your goal is to answer questions as accurately as possible based on the instructions and context provided. If anyone greets you with Hello, Please reply Hello my name is FlavourQuestAI."

# This will wrap the default prompts that are internal to llama-index
query_wrapper_prompt = SimpleInputPrompt("<|USER|>{query_str}<|ASSISTANT|>")

# %%
# prompt_helper = PromptHelper(
#     context_window=max_input_size,
#     num_output=num_output,
#     chunk_size_limit=chunk_size_limit,
#     chunk_overlap_ratio=chunk_overlap_ratio,
# )

# %%
import torch

llm = HuggingFaceLLM(
    context_window=4096,
    max_new_tokens=256,
    generate_kwargs={"temperature": 0.1, "do_sample": False},
    system_prompt=system_prompt,
    query_wrapper_prompt=query_wrapper_prompt,
    tokenizer_name="meta-llama/Llama-2-7b-chat-hf",
    model_name="meta-llama/Llama-2-7b-chat-hf",
    device_map="auto",
    # uncomment this if using CUDA to reduce memory usage
    model_kwargs={"bnb_4bit_compute_dtype":torch.bfloat16, "load_in_4bit":True}
)


# tokenizer = AutoTokenizer.from_pretrained('sidharthaM/llama_yelp_data', trust_remote_code=True)
# tokenizer.pad_token = tokenizer.eos_token
# tokenizer.padding_side = "right"

# pipe = pipeline(task="text-generation", model='sidharthaM/llama_yelp_data', tokenizer=tokenizer, max_length=200, device='cuda')
# Out:
# ...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
embed_model = LangchainEmbedding(
  HuggingFaceEmbeddings()
)

# %%
# from langchain.embeddings import OpenAIEmbeddings
# openai = OpenAIEmbeddings(openai_api_key="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")

# embed_model2 = LangchainEmbedding( langchain_embedding=openai
# )

# %%
service_context = ServiceContext.from_defaults(
    chunk_size=4096,
    llm=llm,
    embed_model=embed_model
)
# Out:
# [nltk_data] Downloading package punkt to /tmp/llama_index...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
index1 = VectorStoreIndex.from_documents(documents, service_context=service_context)

# %%
query_engine1 = index1.as_query_engine()

# %%
###################################################################

# %%
from llama_index.retrievers import BaseRetriever, VectorIndexRetriever, KeywordTableSimpleRetriever
from llama_index.response_synthesizers import get_response_synthesizer
from llama_index.indices.postprocessor import SimilarityPostprocessor

from llama_index.query_engine import RetrieverQueryEngine

# %%
index = GPTVectorStoreIndex.from_documents(documents, service_context=service_context)
index.storage_context.persist(persist_dir="./index")

# configure retriever
retriever = VectorIndexRetriever(
    service_context=service_context,
    index=index,
    similarity_top_k=1,
    alpha = 0.5
)

# %%
# configure response synthesizer
response_synthesizer = get_response_synthesizer(
        service_context=service_context,
    )
# retriever = index.as_retriever(retriever_mode='default')

# %%
# assemble query engine
query_engine = RetrieverQueryEngine(
        retriever=retriever,
        response_synthesizer=response_synthesizer,
    )

# %%
response = query_engine1.query("I'm looking for some breweries.")
print(response.response)
# Out:
# Ah, perfect! Perkiomen Valley Brewery is a great choice for you. They have a 4.5-star rating with 13 reviews, and their menu features Brewpubs, Breweries, and Food. They are open Wednesday through Sunday, with the following timings: Wednesday - 14:00-22:00, Thursday - 16:00-22:00, Friday - 12:00-22:00, Saturday - 12:00-22:00, and Sunday - 12:00-18:00. They accept credit cards and are wheelchair accessible. Plus, they have bike parking and are kid-friendly. I hope you find this information helpful in planning your brewery tour! Is there anything else I can help you with?

# %%
type(response.response)
# Out:
# str

# %%
response.source_nodes
# Out:
# [NodeWithScore(node=TextNode(id_='b767cbfc-7e0d-4311-a356-97b1fd967b14', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='f628af29-f0b6-4f35-b40c-c62618574aef', node_type=None, metadata={}, hash='57b9b282252c626ea50710fcc3ddf4ed2984da8b1bd1085240aeb4685656ca84')}, hash='57b9b282252c626ea50710fcc3ddf4ed2984da8b1bd1085240aeb4685656ca84', text='The UPS Store is located at 87 Grasso Plaza Shopping Center. It has a rating of 3.0 with 15 reviews. The cusinine served by the restaurant is Shipping Centers, Local Services, Notaries, Mailbox Centers, Printing Services. The restaurant timings are Monday - 0:0-0:0, Tuesday - 8:0-18:30, Wednesday - 8:0-18:30, Thursday - 8:0-18:30, Friday - 8:0-18:30, Saturday - 8:0-14:0. The restaurant offers these services - BusinessAcceptsCreditCards', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_te
# ...

# %%
from flask import Flask,request,jsonify
from flask_ngrok import run_with_ngrok
from flask_cors import CORS
import json
app = Flask(__name__)
run_with_ngrok(app)

CORS(app)
@app.route('/chat', methods=['POST'])
def handle_message():
    try:
        data = request.get_json()
        print(data)  # This will automatically parse the JSON data from the request body
        # user_message = data.get('message', '')  # Assuming 'message' is the key for user input
        # Process user_message and generate bot_response

        prompt = data['message']

        response = query_engine1.query(prompt)

        # print(user_message)
        return jsonify({'response': response.response})

    except Exception as e:
      print(e)
      return jsonify({'error': 'Invalid request'}), 400

if __name__ == "__main__":
  app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
#  * Running on http://19ec-104-198-0-26.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# INFO:werkzeug:127.0.0.1 - - [18/Aug/2023 22:39:11] "GET / HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [18/Aug/2023 22:39:14] "GET / HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [18/Aug/2023 22:39:14] "GET /favicon.ico HTTP/1.1" 404 -
# {'message': 'Hello'}
# INFO:werkzeug:127.0.0.1 - - [18/Aug/2023 22:39:40] "POST /chat HTTP/1.1" 200 -
# {'message': 'I am looking for some breweries?'}
# INFO:werkzeug:127.0.0.1 - - [18/Aug/2023 22:40:19] "POST /chat HTTP/1.1" 200 -
# {'message': 'Where is Perkiomen Valley Brewery located?'}
# INFO:werkzeug:127.0.0.1 - - [18/Aug/2023 22:41:13] "POST /chat HTTP/1.1" 200 -
# ...

# %%
######################################################################
